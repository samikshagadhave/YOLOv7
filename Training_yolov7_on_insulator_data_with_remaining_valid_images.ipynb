jpg'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
import cv2
import os
import random
label_folder = r'/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1/valid/labels'
raw_images_folder = r'/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1/valid/images'
save_images_folder = r'/content/yolov7/save_images_valid'
name_list_path = r'/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1/valid/labels'
classes_path = r'/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1'
image_name=r'./runs/detect/exp16/3588_jpg.rf.e7669152a4fab24e91f7cbc7015ccb75.jpg'
label=name_of_class='normalinsulator'

def plot_one_box(x, image, color=None, label=name_of_class,line_thickness=None):

    tl = line_thickness or round(0.002 * (image.shape[0] + image.shape[1]) / 2) + 1  # line/font thickness
    color = color or [random.randint(0, 255) for _ in range(3)]
    c1, c2 = (int(x[0]), int(x[1])), (int(x[2]), int(x[3]))
    cv2.rectangle(image, c1, c2, color, thickness=tl, lineType=cv2.LINE_AA)
    if label:
        tf = max(tl - 1, 1)  # font thickness
        t_size = cv2.getTextSize(str(label), 0, fontScale=tl / 3,thickness=tf)[0]
        c2 = c1[0] + t_size[0], c1[1] - t_size[1] - 3
        cv2.rectangle(image, c1, c2, color, -1, cv2.LINE_AA)  # filled
        cv2.putText(image, str(label), (c1[0], c1[1] - 2), 0, tl / 3, [225, 255, 255], thickness=tf, lineType=cv2.LINE_AA)
def draw_box_on_image(image_name, classes_path, label_folder, raw_images_folder, save_images_folder ):
    txt_path  = r"/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1/valid/labels/3588_jpg.rf.e7669152a4fab24e91f7cbc7015ccb75.txt"
    print(image_name)
    if image_name == '.DS_Store':
        return 0
    image_path = r"./runs/detect/exp16/3588_jpg.rf.e7669152a4fab24e91f7cbc7015ccb75.jpg"
    save_file_path = r"/content/yolov7/save_images_valid/3588"
    source_file = open(txt_path) if os.path.exists(txt_path) else []
    image = cv2.imread(image_path)
    try:
        height, width, channels = image.shape
    except:
        print('no shape info.')
        return 0
    box_number = 0
    for line in source_file:
        staff = line.split()
        class_idx = int(staff[0])
        x_center, y_center, w, h = float(staff[1])*width, float(staff[2])*height, float(staff[3])*width, float(staff[4])*height
        x1 = round(x_center-w/2)
        y1 = round(y_center-h/2)
        x2 = round(x_center+w/2)
        y2 = round(y_center+h/2)
        plot_one_box([x1,y1,x2,y2], image,  label=name_of_class, line_thickness=None)
        cv2.imwrite(r"/content/yolov7/save_images_valid/3588.jpg",image)
        box_number += 1
        return box_number
draw_box_on_image(image_name, classes_path,  label_folder, raw_images_folder, save_images_folder )
# Out:
# ./runs/detect/exp16/3588_jpg.rf.e7669152a4fab24e91f7cbc7015ccb75.jpg
# 1

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --conf 0.1 --source {dataset.location}/valid/images/3598_jpg.rf.5c879c0a8366fea68e78f79036786701.jpg
# Out:
# Namespace(weights=['runs/train/exp/weights/best.pt'], source='/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1/valid/images/3598_jpg.rf.5c879c0a8366fea68e78f79036786701.jpg', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
import glob
from IPython.display import Image, display

i = 0
limit = 10000 # max images to print
for imageName in glob.glob('./runs/detect/exp17/3598_jpg.rf.5c879c0a8366fea68e78f79036786701.jpg'): #assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %%
import cv2
import os
import random
label_folder = r'/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1/valid/labels'
raw_images_folder = r'/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1/valid/images'
save_images_folder = r'/content/yolov7/save_images_valid'
name_list_path = r'/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1/valid/labels'
classes_path = r'/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1'
image_name=r'./runs/detect/exp17/3598_jpg.rf.5c879c0a8366fea68e78f79036786701.jpg'
label=name_of_class='normalinsulator'

def plot_one_box(x, image, color=None, label=name_of_class,line_thickness=None):

    tl = line_thickness or round(0.002 * (image.shape[0] + image.shape[1]) / 2) + 1  # line/font thickness
    color = color or [random.randint(0, 255) for _ in range(3)]
    c1, c2 = (int(x[0]), int(x[1])), (int(x[2]), int(x[3]))
    cv2.rectangle(image, c1, c2, color, thickness=tl, lineType=cv2.LINE_AA)
    if label:
        tf = max(tl - 1, 1)  # font thickness
        t_size = cv2.getTextSize(str(label), 0, fontScale=tl / 3,thickness=tf)[0]
        c2 = c1[0] + t_size[0], c1[1] - t_size[1] - 3
        cv2.rectangle(image, c1, c2, color, -1, cv2.LINE_AA)  # filled
        cv2.putText(image, str(label), (c1[0], c1[1] - 2), 0, tl / 3, [225, 255, 255], thickness=tf, lineType=cv2.LINE_AA)
def draw_box_on_image(image_name, classes_path, label_folder, raw_images_folder, save_images_folder ):
    txt_path  = r"/content/yolov7/Normal-Insulator,-Defect-Insulator,-Defects-2-1/valid/labels/3598_jpg.rf.5c879c0a8366fea68e78f79036786701.txt"
    print(image_name)
    if image_name == '.DS_Store':
        return 0
    image_path = r"./runs/detect/exp17/3598_jpg.rf.5c879c0a8366fea68e78f79036786701.jpg"
    save_file_path = r"/content/yolov7/save_images_valid/3598"
    source_file = open(txt_path) if os.path.exists(txt_path) else []
    image = cv2.imread(image_path)
    try:
        height, width, channels = image.shape
    except:
        print('no shape info.')
        return 0
    box_number = 0
    for line in source_file:
        staff = line.split()
        class_idx = int(staff[0])
        x_center, y_center, w, h = float(staff[1])*width, float(staff[2])*height, float(staff[3])*width, float(staff[4])*height
        x1 = round(x_center-w/2)
        y1 = round(y_center-h/2)
        x2 = round(x_center+w/2)
        y2 = round(y_center+h/2)
        plot_one_box([x1,y1,x2,y2], image,  label=name_of_class, line_thickness=None)
        cv2.imwrite(r"/content/yolov7/save_images_valid/3598.jpg",image)
        box_number += 1
        return box_number
draw_box_on_image(image_name, classes_path,  label_folder, raw_images_folder, save_images_folder )
# Out:
# ./runs/detect/exp17/3598_jpg.rf.5c879c0a8366fea68e78f79036786701.jpg
# 1
